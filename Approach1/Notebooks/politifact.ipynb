# %%
import pandas as pd

df = pd.read_csv('../datasets/politifact_graph_features.csv')
df.head()
# Out:
#   label  num_nodes  num_tweets  avg_num_retweet  retweet_perc  num_users  \
# 0  fake        124          82         0.500000      0.338710        122
# 1  fake         12           9         0.222222      0.250000         11
# 2  fake         59          40         0.450000      0.322034         47
# 3  fake        333         219         0.515982      0.342342        316
# 4  fake       1530         712         1.147472      0.534641       1421
#
#    total_propagation_time  avg_num_followers  avg_num_friends  avg_time_diff  \
# 0            1.454356e+09        6980.203252      5410.723577   66045.631151
# 1            1.486939e+09        2670.454545      1903.000000   28906.500000
# 2            1.543481e+09        3597.689655       871.879310   41604.900000
# 3            1.524245e+09      109006.966867      2361.521084  160908.689676
# 4            1.506620e+09        3942.915631      3699.542184   90408.423591
#
#    perc_post_1_hour  users_10h               id
# 0          0.153226         88  politifact11773
# 1          0.083333          1  politifact13038
# 2          0.610169         23  politifact13467
# 3          0.453453        207  politifact13468
# 4          0.001307          3  politifact13475

# %%
from pandas_profiling import ProfileReport
profile = ProfileReport(df, title="Politifact EDA")

# %%
profile.to_file("politifact_eda.html")
# Out:
# Summarize dataset: 100%|██████████| 147/147 [00:39<00:00,  3.74it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:05<00:00,  5.35s/it]
# Render HTML: 100%|██████████| 1/1 [00:05<00:00,  5.98s/it]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 11.36it/s]

# %%
# Politifact dataset statistics

data = [
    ("news_articles", len(df[df['label'] == "fake"]), len(df[df['label'] == "real"])),
    ("tweets", df[df['label'] == "fake"]['num_tweets'].sum(), df[df['label'] == "real"]['num_tweets'].sum()),
    ("unique_users", df[df['label'] == "fake"]['num_users'].sum(), df[df['label'] == "real"]['num_users'].sum())
]

pd.DataFrame(data=data, columns=["type", 'fake', "real"]).set_index("type")
# Out:
#                  fake    real
# type
# news_articles     322     263
# tweets         108922  224265
# unique_users   172054  493966

# %%
df.groupby("label").mean().apply(lambda s: s.apply('{0:.3f}'.format))
# Out:
#       num_nodes num_tweets avg_num_retweet retweet_perc num_users  \
# label
# fake    631.748    338.267           0.848        0.362   534.329
# real   2278.433    852.719           1.036        0.404  1878.198
#
#       total_propagation_time avg_num_followers avg_num_friends avg_time_diff  \
# label
# fake          1516524227.149          8714.431        3346.605     96954.436
# real          1458752351.224         59140.746        2936.060    398690.436
#
#       perc_post_1_hour users_10h
# label
# fake             0.383   157.531
# real             0.472   211.951

# %%
df.groupby("label").std().apply(lambda s: s.apply('{0:.3f}'.format))
# Out:
#       num_nodes num_tweets avg_num_retweet retweet_perc num_users  \
# label
# fake   3256.580   1418.470           1.297        0.218  2479.548
# real   6679.075   2298.408           1.853        0.227  5518.158
#
#       total_propagation_time avg_num_followers avg_num_friends avg_time_diff  \
# label
# fake            19975265.673         17490.121        3057.385    436228.010
# real           104670391.829        303544.730        4070.050   3961482.683
#
#       perc_post_1_hour users_10h
# label
# fake             0.400   391.242
# real             0.349   329.953

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['label'] = le.fit_transform(df['label'])

X_train, X_test, y_train, y_test = train_test_split(df.drop(['label', 'id'], axis=1), df['label'], test_size=0.33)

# %%
from sklearn.model_selection import KFold

kf = KFold(n_splits=10, shuffle=True)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression, RidgeClassifier, PassiveAggressiveClassifier, SGDClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, HistGradientBoostingClassifier, \
    GradientBoostingClassifier, BaggingClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import LinearSVC
from sklearn.preprocessing import StandardScaler

params = {
    'estimator': [
        LogisticRegression(), RidgeClassifier(), PassiveAggressiveClassifier(), SGDClassifier(), LinearSVC(max_iter=20000),
        RandomForestClassifier(), ExtraTreesClassifier(), 
        HistGradientBoostingClassifier(), GradientBoostingClassifier(), 
        BaggingClassifier(), AdaBoostClassifier(),
        KNeighborsClassifier(), 
        GaussianProcessClassifier(),
        GaussianNB()
    ]
}

pipeline = Pipeline([
    ('scaling', StandardScaler()),
    ('estimator', LogisticRegression())
])

gs = GridSearchCV(pipeline, params, cv=kf, scoring="f1_weighted")
gs.fit(X_train, y_train)
results = pd.DataFrame(data=gs.cv_results_)
results.sort_values('rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 5        0.316088      0.122771         0.025611        0.007568
# 7        0.574473      0.297616         0.029625        0.062365
# 8        0.218050      0.087862         0.006126        0.004957
# 9        0.041306      0.017015         0.005660        0.004160
# 10       0.126114      0.098462         0.011870        0.007396
# 6        0.155997      0.046673         0.018099        0.007421
# 4        0.152285      0.087919         0.002808        0.003454
# 11       0.012730      0.029139         0.011115        0.007341
# 0        0.171105      0.403578         0.009619        0.008241
# 12       0.288191      0.207319         0.010709        0.021739
# 13       0.005257      0.007276         0.009364        0.007646
# 1        0.204499      0.571180         0.007525        0.003620
# 3        0.008112      0.005338         0.005390        0.004614
# 2        0.091310      0.234076         0.005638        0.004808
#
#                      param_estimator  \
# 5           RandomForestClassifier()
# 7   HistGradientBoostingClassifier()
# 8       GradientBoostingClassifier()
# 9                BaggingClassifier()
# 10              AdaBoostClassifier()
# 6             ExtraTreesClassifier()
# 4          LinearSVC(max_iter=20000)
# 11            KNeighborsClassifier()
# 0               LogisticRegression()
# 12       GaussianProcessClassifier()
# 13                      GaussianNB()
# 1                  RidgeClassifier()
# 3                    SGDClassifier()
# 2      PassiveAggressiveClassifier()
#
#                                              params  split0_test_score  \
# 5           {'estimator': RandomForestClassifier()}           0.850000
# 7   {'estimator': HistGradientBoostingClassifier()}           0.850000
# 8       {'estimator': GradientBoostingClassifier()}           0.850000
# 9                {'estimator': BaggingClassifier()}           0.900000
# 10              {'estimator': AdaBoostClassifier()}           0.848437
# 6             {'estimator': ExtraTreesClassifier()}           0.850000
# 4          {'estimator': LinearSVC(max_iter=20000)}           0.875397
# 11            {'estimator': KNeighborsClassifier()}           0.773985
# 0               {'estimator': LogisticRegression()}           0.801010
# 12       {'estimator': GaussianProcessClassifier()}           0.771001
# 13                      {'estimator': GaussianNB()}           0.743333
# 1                  {'estimator': RidgeClassifier()}           0.720112
# 3                    {'estimator': SGDClassifier()}           0.626173
# 2      {'estimator': PassiveAggressiveClassifier()}           0.698000
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 5            0.894605           0.745304           0.872313
# 7            0.841908           0.767964           0.846154
# 8            0.894605           0.821944           0.846154
# 9            0.846154           0.795682           0.844231
# 10           0.922104           0.821944           0.819527
# 6            0.894605           0.719088           0.794872
# 4            0.804501           0.719808           0.705659
# 11           0.804501           0.694364           0.816724
# 0            0.836074           0.720198           0.735531
# 12           0.841908           0.617920           0.812692
# 13           0.812416           0.709703           0.674556
# 1            0.804501           0.694750           0.728797
# 3            0.818243           0.664836           0.490607
# 2            0.804501           0.694750           0.424705
#
#     split4_test_score  split5_test_score  split6_test_score  \
# 5            0.845543           0.844231           0.793244
# 7            0.897029           0.844231           0.819803
# 8            0.870773           0.788425           0.766164
# 9            0.844097           0.792308           0.743252
# 10           0.792129           0.764359           0.819803
# 6            0.845543           0.792308           0.819803
# 4            0.841764           0.591492           0.815436
# 11           0.760361           0.688462           0.665348
# 0            0.784615           0.591492           0.815436
# 12           0.760361           0.711994           0.741555
# 13           0.784615           0.570469           0.663297
# 1            0.754615           0.551764           0.673077
# 3            0.717949           0.720198           0.766164
# 2            0.792129           0.642013           0.636227
#
#     split7_test_score  split8_test_score  split9_test_score  mean_test_score  \
# 5            0.820513           0.819803           0.923077         0.840863
# 7            0.846154           0.689866           0.897029         0.830014
# 8            0.794602           0.794602           0.870773         0.829804
# 9            0.743252           0.819803           0.897436         0.822621
# 10           0.794602           0.766164           0.845543         0.819461
# 6            0.793244           0.715700           0.871795         0.809696
# 4            0.762704           0.659933           0.794872         0.757157
# 11           0.741555           0.740162           0.846154         0.753162
# 0            0.709972           0.659933           0.794872         0.744913
# 12           0.709972           0.659933           0.820513         0.744785
# 13           0.650194           0.668132           0.762704         0.703942
# 1            0.673077           0.630783           0.716833         0.694831
# 3            0.640863           0.641026           0.589204         0.667526
# 2            0.638177           0.494096           0.790758         0.661536
#
#     std_test_score  rank_test_score
# 5         0.047969                1
# 7         0.058174                2
# 8         0.040662                3
# 9         0.052267                4
# 10        0.043936                5
# 6         0.056494                6
# 4         0.083171                7
# 11        0.056095                8
# 0         0.072926                9
# 12        0.068045               10
# 13        0.069148               11
# 1         0.065875               12
# 3         0.088502               13
# 2         0.119297               14

# %%
gs.best_estimator_.score(X_test, y_test)
# Out:
# 0.8556701030927835
