# %%
import pandas as pd

df = pd.read_csv('../datasets/politifact_graph_features.csv')
df.head()
# Out:
#   label  num_nodes  num_tweets  avg_num_retweet  retweet_perc  num_users  \
# 0  fake        124          82         0.500000      0.338710        122
# 1  fake         12           9         0.222222      0.250000         11
# 2  fake         59          40         0.450000      0.322034         47
# 3  fake        333         219         0.515982      0.342342        316
# 4  fake       1530         712         1.147472      0.534641       1421
#
#    total_propagation_time  avg_num_followers  avg_num_friends  avg_time_diff  \
# 0            1.454356e+09        6980.203252      5410.723577   66045.631151
# 1            1.486939e+09        2670.454545      1903.000000   28906.500000
# 2            1.543481e+09        3597.689655       871.879310   41604.900000
# 3            1.524245e+09      109006.966867      2361.521084  160908.689676
# 4            1.506620e+09        3942.915631      3699.542184   90408.423591
#
#    perc_post_1_hour  users_10h               id
# 0          0.153226         88  politifact11773
# 1          0.083333          1  politifact13038
# 2          0.610169         23  politifact13467
# 3          0.453453        207  politifact13468
# 4          0.001307          3  politifact13475

# %%
from pandas_profiling import ProfileReport
profile = ProfileReport(df, title="Politifact EDA")

# %%
profile.to_file("politifact_eda.html")
# Out:
# Summarize dataset: 100%|██████████| 147/147 [00:39<00:00,  3.74it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:05<00:00,  5.35s/it]
# Render HTML: 100%|██████████| 1/1 [00:05<00:00,  5.98s/it]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 11.36it/s]

# %%
# Politifact dataset statistics

data = [
    ("news_articles", len(df[df['label'] == "fake"]), len(df[df['label'] == "real"])),
    ("tweets", df[df['label'] == "fake"]['num_tweets'].sum(), df[df['label'] == "real"]['num_tweets'].sum()),
    ("unique_users", df[df['label'] == "fake"]['num_users'].sum(), df[df['label'] == "real"]['num_users'].sum())
]

pd.DataFrame(data=data, columns=["type", 'fake', "real"]).set_index("type")
# Out:
#                  fake    real
# type
# news_articles     385     404
# tweets         114151  310891
# unique_users   182040  690963

# %%
df.groupby("label").mean().apply(lambda s: s.apply('{0:.3f}'.format))
# Out:
#       num_nodes num_tweets avg_num_retweet retweet_perc num_users  \
# label
# fake    556.431    296.496           0.892        0.364   472.831
# real   2071.842    769.532           0.979        0.402  1710.304
#
#       total_propagation_time avg_num_followers avg_num_friends avg_time_diff  \
# label
# fake          1515281458.203          7984.711        3258.577    105159.395
# real          1454351859.653         50191.299        2832.341    292362.515
#
#       perc_post_1_hour users_10h
# label
# fake             0.366   138.335
# real             0.481   193.641

# %%
df.groupby("label").std().apply(lambda s: s.apply('{0:.3f}'.format))
# Out:
#       num_nodes num_tweets avg_num_retweet retweet_perc num_users  \
# label
# fake   2984.767   1301.321           1.599        0.220  2273.992
# real   6032.508   2047.832           1.720        0.227  4968.101
#
#       total_propagation_time avg_num_followers avg_num_friends avg_time_diff  \
# label
# fake            19592017.396         16188.196        2958.628    433041.423
# real           109255603.808        255783.479        3770.064   3202275.354
#
#       perc_post_1_hour users_10h
# label
# fake             0.392   362.367
# real             0.339   313.196

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['label'] = le.fit_transform(df['label'])

X_train, X_test, y_train, y_test = train_test_split(df.drop(['label', 'id'], axis=1), df['label'], test_size=0.33)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

# %%
from sklearn.linear_model import LogisticRegression, RidgeClassifier, PassiveAggressiveClassifier, SGDClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, HistGradientBoostingClassifier, \
    GradientBoostingClassifier, BaggingClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import LinearSVC
from sklearn.preprocessing import StandardScaler

params = {
    'estimator': [
        LogisticRegression(), RidgeClassifier(), PassiveAggressiveClassifier(), SGDClassifier(), LinearSVC(max_iter=20000),
        RandomForestClassifier(), ExtraTreesClassifier(), 
        HistGradientBoostingClassifier(), GradientBoostingClassifier(), 
        BaggingClassifier(), AdaBoostClassifier(),
        KNeighborsClassifier(), 
        GaussianProcessClassifier(),
        GaussianNB()
    ]
}

pipeline = Pipeline([
    ('scaling', StandardScaler()),
    ('estimator', LogisticRegression())
])

gs = GridSearchCV(pipeline, params, cv=10, scoring="f1_weighted")
gs.fit(X_train, y_train)
results = pd.DataFrame(data=gs.cv_results_)
results.sort_values('rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 8        0.345484      0.008636         0.005426        0.000387
# 5        0.337831      0.102772         0.024155        0.015871
# 7        0.819527      0.039292         0.012049        0.001587
# 10       0.186053      0.002869         0.019958        0.000729
# 9        0.068421      0.001415         0.007609        0.000468
# 6        0.305224      0.085187         0.031458        0.006678
# 12       0.374826      0.017440         0.007390        0.000500
# 4        0.081207      0.020676         0.005244        0.001548
# 0        0.035257      0.012677         0.006980        0.002813
# 11       0.009549      0.000490         0.009991        0.000378
# 13       0.007858      0.000259         0.004774        0.000407
# 3        0.007777      0.002219         0.004148        0.000789
# 1        0.006484      0.000953         0.002844        0.000266
# 2        0.006416      0.001199         0.003300        0.000762
#
#                      param_estimator  \
# 8       GradientBoostingClassifier()
# 5           RandomForestClassifier()
# 7   HistGradientBoostingClassifier()
# 10              AdaBoostClassifier()
# 9                BaggingClassifier()
# 6             ExtraTreesClassifier()
# 12       GaussianProcessClassifier()
# 4          LinearSVC(max_iter=20000)
# 0               LogisticRegression()
# 11            KNeighborsClassifier()
# 13                      GaussianNB()
# 3                    SGDClassifier()
# 1                  RidgeClassifier()
# 2      PassiveAggressiveClassifier()
#
#                                              params  split0_test_score  \
# 8       {'estimator': GradientBoostingClassifier()}           0.811321
# 5           {'estimator': RandomForestClassifier()}           0.811321
# 7   {'estimator': HistGradientBoostingClassifier()}           0.773424
# 10              {'estimator': AdaBoostClassifier()}           0.811186
# 9                {'estimator': BaggingClassifier()}           0.829459
# 6             {'estimator': ExtraTreesClassifier()}           0.811186
# 12       {'estimator': GaussianProcessClassifier()}           0.811321
# 4          {'estimator': LinearSVC(max_iter=20000)}           0.728877
# 0               {'estimator': LogisticRegression()}           0.711207
# 11            {'estimator': KNeighborsClassifier()}           0.716779
# 13                      {'estimator': GaussianNB()}           0.725039
# 3                    {'estimator': SGDClassifier()}           0.731829
# 1                  {'estimator': RidgeClassifier()}           0.733951
# 2      {'estimator': PassiveAggressiveClassifier()}           0.621024
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 8            0.904640           0.886792           0.830068
# 5            0.867357           0.962183           0.791561
# 7            0.886550           0.924528           0.773100
# 10           0.867830           0.905593           0.749713
# 9            0.866496           0.886550           0.792453
# 6            0.867357           0.886550           0.790207
# 12           0.826724           0.904640           0.720240
# 4            0.846760           0.885979           0.702963
# 0            0.846760           0.867357           0.697268
# 11           0.828352           0.866496           0.720240
# 13           0.764319           0.785558           0.673579
# 3            0.788219           0.828352           0.634196
# 1            0.846760           0.848733           0.640309
# 2            0.504148           0.772615           0.584016
#
#     split4_test_score  split5_test_score  split6_test_score  \
# 8            0.791561           0.848733           0.829825
# 5            0.792305           0.830068           0.772615
# 7            0.811321           0.773585           0.848949
# 10           0.735849           0.867925           0.830189
# 9            0.829459           0.792453           0.771145
# 6            0.753663           0.830189           0.771145
# 12           0.731829           0.886792           0.789309
# 4            0.749713           0.792009           0.789309
# 0            0.749713           0.810512           0.771145
# 11           0.752063           0.829825           0.712695
# 13           0.767609           0.789309           0.762466
# 3            0.713919           0.830068           0.754542
# 1            0.693519           0.829825           0.751002
# 2            0.659650           0.698113           0.751002
#
#     split7_test_score  split8_test_score  split9_test_score  mean_test_score  \
# 8            0.735661           0.942286           0.845238         0.842613
# 5            0.772615           0.865335           0.845238         0.831060
# 7            0.773424           0.846154           0.825308         0.823634
# 10           0.697898           0.884444           0.826859         0.817749
# 9            0.694860           0.864935           0.825308         0.815312
# 6            0.773424           0.884615           0.769231         0.813757
# 12           0.751002           0.823729           0.710575         0.795616
# 4            0.727134           0.787755           0.766117         0.777662
# 0            0.727134           0.768889           0.710575         0.766056
# 11           0.653486           0.788383           0.651786         0.752011
# 13           0.705489           0.766117           0.760369         0.749985
# 3            0.621024           0.749908           0.742280         0.739434
# 1            0.666221           0.749908           0.633395         0.739362
# 2            0.722877           0.788383           0.671985         0.677381
#
#     std_test_score  rank_test_score
# 8         0.055788                1
# 5         0.054928                2
# 7         0.050538                3
# 10        0.065705                4
# 9         0.053068                5
# 6         0.048021                6
# 12        0.064200                7
# 4         0.053271                8
# 0         0.056023                9
# 11        0.070613               10
# 13        0.035060               11
# 3         0.066822               12
# 1         0.077748               13
# 2         0.084591               14

# %%
gs.best_estimator_.score(X_test, y_test)
# Out:
# 0.8582375478927203
