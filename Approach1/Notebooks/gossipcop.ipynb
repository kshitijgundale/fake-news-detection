# %%
import pandas as pd

df = pd.read_csv('../datasets/gossipcop_graph_features.csv')
df.head()
# Out:
#   label  num_nodes  num_tweets  avg_num_retweet  retweet_perc  num_users  \
# 0  fake        116         110         0.045455      0.051724         61
# 1  fake          5           3         0.333333      0.400000          3
# 2  fake          3           2         0.000000      0.333333          1
# 3  fake         15          10         0.400000      0.333333         14
# 4  fake         30          22         0.318182      0.266667         21
#
#    total_propagation_time  avg_num_followers  avg_num_friends  avg_time_diff  \
# 0            1.525941e+09       20970.565217      1149.026087  743706.000000
# 1            1.485491e+09      158959.750000       791.750000    6278.000000
# 2            1.495247e+09      317729.000000       723.000000       0.000000
# 3            1.496761e+09       26939.000000      3446.928571    2765.666667
# 4            1.530403e+09       30835.965517      5045.862069   12419.083333
#
#    perc_post_1_hour  users_10h                    id
# 0          0.991379         56  gossipcop-1000240645
# 1          0.200000          2  gossipcop-1000908841
# 2          0.333333          1  gossipcop-1009248558
# 3          0.466667          7  gossipcop-1012123555
# 4          0.166667         11  gossipcop-1014383679

# %%
import os
p = "../../preprocessed_data/gossipcop"

for label in ['fake', 'real']:
    for news in os.listdir(os.path.join(p, label)):
        with open(os.path.join(p, label, news, f'{news}_text.txt'), 'r', encoding='utf-8') as f:
            text = f.read()
        if not text:
            df[df.label != news]
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# C:\Users\KSHITI~1\AppData\Local\Temp/ipykernel_5048/589332368.py in <module>
#       4 for label in ['fake', 'real']:
#       5     for news in os.listdir(os.path.join(p, label)):
# ----> 6         with open(os.path.join(p, label, news), 'r', encoding='utf-8') as f:
#       7             text = f.read()
#       8         if not text:
#
# PermissionError: [Errno 13] Permission denied: '../../preprocessed_data/gossipcop\\fake\\gossipcop-1000240645'

# %%
from pandas_profiling import ProfileReport
profile = ProfileReport(df, title="Politifact EDA")

# %%
profile.to_file("politifact_eda.html")

# %%
# Politifact dataset statistics

data = [
    ("news_articles", len(df[df['label'] == "fake"]), len(df[df['label'] == "real"])),
    ("tweets", df[df['label'] == "fake"]['num_tweets'].sum(), df[df['label'] == "real"]['num_tweets'].sum()),
    ("unique_users", df[df['label'] == "fake"]['num_users'].sum(), df[df['label'] == "real"]['num_users'].sum())
]

pd.DataFrame(data=data, columns=["type", 'fake', "real"]).set_index("type")
# Out:
#                  fake    real
# type
# news_articles    5059   15648
# tweets         451452  759356
# unique_users   624147  805647

# %%
df.groupby("label").mean().apply(lambda s: s.apply('{0:.3f}'.format))
# Out:
#       num_nodes num_tweets avg_num_retweet retweet_perc num_users  \
# label
# fake    154.351     89.237           0.427        0.288   123.374
# real     60.615     48.527           0.157        0.136    51.486
#
#       total_propagation_time avg_num_followers avg_num_friends avg_time_diff  \
# label
# fake          1515784986.334         70546.463        2339.371     86132.982
# real          1513359948.575         34896.594        2329.693     55941.102
#
#       perc_post_1_hour users_10h
# label
# fake             0.373    41.781
# real             0.415    37.991

# %%
df.groupby("label").std().apply(lambda s: s.apply('{0:.3f}'.format))
# Out:
#       num_nodes num_tweets avg_num_retweet retweet_perc num_users  \
# label
# fake    409.015    212.531           1.070        0.190   323.564
# real    112.205     66.347           0.830        0.176    96.085
#
#       total_propagation_time avg_num_followers avg_num_friends avg_time_diff  \
# label
# fake            20532042.796        103568.428        3279.721    594777.349
# real            12430112.648        138713.122        2313.495    637970.696
#
#       perc_post_1_hour users_10h
# label
# fake             0.289   115.867
# real             0.243    49.698

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler()
X_res, y_res = rus.fit_resample(df.drop(['label', 'id'], axis=1), df['label'])

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['label'] = le.fit_transform(df['label'])

X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.33)

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits=10, shuffle=True)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression, RidgeClassifier, PassiveAggressiveClassifier, SGDClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, HistGradientBoostingClassifier, \
    GradientBoostingClassifier, BaggingClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import LinearSVC
from sklearn.preprocessing import StandardScaler

params = {
    'estimator': [
        LogisticRegression(), RidgeClassifier(), PassiveAggressiveClassifier(), SGDClassifier(), LinearSVC(max_iter=200000),
        RandomForestClassifier(), ExtraTreesClassifier(), 
        HistGradientBoostingClassifier(), GradientBoostingClassifier(), 
        BaggingClassifier(), AdaBoostClassifier(),
        KNeighborsClassifier(), 
        GaussianProcessClassifier(),
        GaussianNB()
    ]
}

pipeline = Pipeline([
    ('scaling', StandardScaler()),
    ('estimator', LogisticRegression())
])

gs = GridSearchCV(pipeline, params, cv=kf, scoring="f1_weighted")
gs.fit(X_train, y_train)
results = pd.DataFrame(data=gs.cv_results_)
results.sort_values('rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 5        2.141217      0.017821         0.052119        0.008312
# 7        1.843789      0.019087         0.017494        0.005524
# 6        1.094479      0.026645         0.058771        0.006763
# 9        0.508230      0.103816         0.009466        0.002214
# 8        2.432927      0.490395         0.006490        0.004552
# 12      80.153946      6.640584         0.319914        0.061494
# 10       0.641228      0.125223         0.032412        0.015994
# 11       0.036483      0.010974         0.099742        0.067448
# 3        0.057145      0.016216         0.006055        0.003911
# 0        0.138857      0.013189         0.010694        0.002849
# 4       36.405474      4.906023         0.004261        0.005477
# 1        0.016705      0.006605         0.002005        0.001063
# 2        0.019994      0.008552         0.005341        0.002834
# 13       0.010286      0.003581         0.001949        0.002079
#
#                      param_estimator  \
# 5           RandomForestClassifier()
# 7   HistGradientBoostingClassifier()
# 6             ExtraTreesClassifier()
# 9                BaggingClassifier()
# 8       GradientBoostingClassifier()
# 12       GaussianProcessClassifier()
# 10              AdaBoostClassifier()
# 11            KNeighborsClassifier()
# 3                    SGDClassifier()
# 0               LogisticRegression()
# 4         LinearSVC(max_iter=200000)
# 1                  RidgeClassifier()
# 2      PassiveAggressiveClassifier()
# 13                      GaussianNB()
#
#                                              params  split0_test_score  \
# 5           {'estimator': RandomForestClassifier()}           0.905595
# 7   {'estimator': HistGradientBoostingClassifier()}           0.918843
# 6             {'estimator': ExtraTreesClassifier()}           0.905605
# 9                {'estimator': BaggingClassifier()}           0.898253
# 8       {'estimator': GradientBoostingClassifier()}           0.901120
# 12       {'estimator': GaussianProcessClassifier()}           0.874660
# 10              {'estimator': AdaBoostClassifier()}           0.879029
# 11            {'estimator': KNeighborsClassifier()}           0.884875
# 3                    {'estimator': SGDClassifier()}           0.741900
# 0               {'estimator': LogisticRegression()}           0.713977
# 4         {'estimator': LinearSVC(max_iter=200000)}           0.704397
# 1                  {'estimator': RidgeClassifier()}           0.693418
# 2      {'estimator': PassiveAggressiveClassifier()}           0.589183
# 13                      {'estimator': GaussianNB()}           0.523725
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 5            0.896559           0.912977           0.904205
# 7            0.884891           0.908510           0.901258
# 6            0.886415           0.892217           0.885034
# 9            0.893746           0.904100           0.874641
# 8            0.865863           0.895248           0.886495
# 12           0.854037           0.873035           0.877677
# 10           0.857161           0.883445           0.868696
# 11           0.845428           0.865614           0.880574
# 3            0.684445           0.700874           0.735865
# 0            0.675132           0.694567           0.729697
# 4            0.668872           0.680021           0.721588
# 1            0.664098           0.676802           0.715780
# 2            0.600674           0.561080           0.643070
# 13           0.475703           0.500945           0.533175
#
#     split4_test_score  split5_test_score  split6_test_score  \
# 5            0.914378           0.898272           0.896804
# 7            0.914395           0.899677           0.901207
# 6            0.892350           0.904110           0.885010
# 9            0.893638           0.892376           0.887960
# 8            0.908521           0.884924           0.898258
# 12           0.882035           0.886271           0.879083
# 10           0.881994           0.862783           0.873185
# 11           0.858444           0.867052           0.873097
# 3            0.732435           0.747494           0.728492
# 0            0.667741           0.717472           0.711503
# 4            0.655568           0.708387           0.703457
# 1            0.659845           0.705313           0.698700
# 2            0.755258           0.701202           0.597815
# 13           0.497846           0.541570           0.526490
#
#     split7_test_score  split8_test_score  split9_test_score  mean_test_score  \
# 5            0.905575           0.899705           0.899502         0.903357
# 7            0.893797           0.902680           0.898083         0.902334
# 6            0.887905           0.892276           0.901001         0.893192
# 9            0.886359           0.902643           0.890576         0.892429
# 8            0.877574           0.884996           0.883318         0.888632
# 12           0.853979           0.883352           0.875873         0.874000
# 10           0.868667           0.874668           0.865600         0.871523
# 11           0.859845           0.876139           0.870027         0.868110
# 3            0.691321           0.692841           0.729705         0.718537
# 0            0.705705           0.697077           0.709770         0.702264
# 4            0.699265           0.687208           0.707950         0.693671
# 1            0.694635           0.691722           0.706302         0.690661
# 2            0.746293           0.613695           0.693309         0.650158
# 13           0.509302           0.495517           0.467852         0.507213
#
#     std_test_score  rank_test_score
# 5         0.006065                1
# 7         0.009279                2
# 6         0.007377                3
# 9         0.008089                4
# 8         0.011783                5
# 12        0.010706                6
# 10        0.008091                7
# 11        0.011014                8
# 3         0.022309                9
# 0         0.018135               10
# 4         0.019331               11
# 1         0.017398               12
# 2         0.065556               13
# 13        0.023041               14

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.model_selection import cross_val_score

stc = StackingClassifier(estimators=[
    ('rfc', RandomForestClassifier()), 
    ('abc', AdaBoostClassifier()), 
    ('gbc', GradientBoostingClassifier()), 
    ('etc', ExtraTreesClassifier())
])

cross_val_score(stc, X_train, y_train, cv=kf, scoring="f1_weighted")
# Out:
# array([0.88942026, 0.92623056, 0.91001168, 0.90263114, 0.92029834,
#        0.89821304, 0.89238462, 0.87610619, 0.8967102 , 0.89359273])

# %%
stc.cv
# Out:
# KFold(n_splits=10, random_state=RandomState(MT19937) at 0x27E2E2CB740,
#    shuffle=True)

# %%
gs.best_estimator_.score(X_test, y_test)
# Out:
# 0.906858340820605
